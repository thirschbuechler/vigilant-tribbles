# %%
try:
    import myink as m
except:
    try:
        import vigilant_tribbles.myink as m
    except:
        print("failed to import module directly or via submodule -  mind adding them with underscores not operators (minuses aka dashes, etc.)")

m.tester()
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
# /home/thomas/git/DA_report1/vigilant_tribbles/myink.py:1650: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(x, k*x + d, 'r', label='Fitted line', c=ele.defaultcolorlist()[1])
# .....saved test_anim.gif
# [1000000. 2000000. 3000000. 4000000.]
# (5, 5)
# (4,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-a2dffb8f517d> in <module>
#       7         print("failed to import module directly or via submodule -  mind adding them with underscores not operators (minuses aka dashes, etc.)")
#       8
# ----> 9 m.tester()
#
# ~/git/DA_report1/vigilant_tribbles/myink.py in tester()
#    1629     myinkc().mycanvassize(medfig=True) # reset afterwards via one-time-use myinkc element
#    1630     test_waterfall()
# -> 1631     histo_test()
#    1632     doublebarrel_barberpole()
#    1633     statistics_visu()
#
# ~/git/DA_report1/vigilant_tribbles/myink.py in histo_test()
#    1693     for percent in [False, True]:
#    1694         ele.title(f"one element 2 times, percent:{percent}")
# -> 1695         ele.hist(x=[1.0,1.0], percent=percent)
#    1696         ele.ax_onward()
#    1697
#
# ~/git/DA_report1/vigilant_tribbles/myink.py in hist(self, percent, *args, **kwargs)
#    1018         kwargs = ml.histo_weighter(kwargs=kwargs, percent=percent)
#    1019
# -> 1020         ret = self.get_ax().hist(*args,**kwargs)
#    1021
#    1022         if percent:
#
# ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: hist() missing 1 required positional argument: 'x'
