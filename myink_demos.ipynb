# %%
try:
    import myink as m
except:
    try:
        import vigilant_tribbles.myink as m
    except:
        print("failed to import module directly or via submodule -  mind adding them with underscores not operators (minuses aka dashes, etc.)")

m.tester()
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
# /home/thomas/git/DA_report1/vigilant_tribbles/myink.py:2072: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(x, k*x + d, 'r', label='Fitted line', c=ele.defaultcolorlist()[1])
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter._run: running command: ffmpeg -f rawvideo -vcodec rawvideo -s 640x480 -pix_fmt rgba -r 1 -loglevel error -i pipe: -filter_complex 'split [a][b];[a] palettegen [p];[b][p] paletteuse' -y test_anim.gif
# .....saved test_anim.gif
# x_axis=array([1000000., 2000000., 3000000., 4000000.]), np.shape(x_axis)=(4,), np.shape(data)=(5, 5)
# x_axis=array([1000000., 2000000., 3000000., 4000000.]), np.shape(x_axis)=(4,), np.shape(data)=(5, 5)
# x_axis=array([1000000., 2000000., 3000000., 4000000.]), np.shape(x_axis)=(4,), np.shape(data)=(5, 5)
# /home/thomas/git/DA_report1/vigilant_tribbles/myink.py:2404: UserWarning: FixedFormatter should only be used together with FixedLocator
#   pe.get_ax().set_yticklabels(yticks, ha="center", position=(-0.1, 0))
