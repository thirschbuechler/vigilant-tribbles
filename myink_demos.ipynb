# %%
try:
    import myink as m
except:
    try:
        import vigilant_tribbles.myink as m
    except:
        print("failed to import module directly or via submodule -  mind adding them with underscores not operators (minuses aka dashes, etc.)")

m.tester()
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
# c:\Users\hirschbuechler\Documents\Github\DA_report1\vigilant_tribbles\myink.py:1393: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(x, k*x + d, 'r', label='Fitted line', c=ele.defaultcolorlist()[1])
# MovieWriter ffmpeg unavailable; using Pillow instead.
# .....saved test_anim.gif
# [1000000. 2000000. 3000000. 4000000.]
# (5, 5)
# (4,)
# c:\Users\hirschbuechler\Documents\Github\DA_report1\vigilant_tribbles\myink.py:1659: UserWarning: FixedFormatter should only be used together with FixedLocator
#   pe.get_ax().set_yticklabels(yticks, ha="center", position=(-0.1, 0))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\hirschbuechler\Documents\Github\DA_report1\vigilant_tribbles\myink_demos.ipynb Zelle 1 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/c%3A/Users/hirschbuechler/Documents/Github/DA_report1/vigilant_tribbles/myink_demos.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a>     except:
#       <a href='vscode-notebook-cell:/c%3A/Users/hirschbuechler/Documents/Github/DA_report1/vigilant_tribbles/myink_demos.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a>         print("failed to import module directly or via submodule -  mind adding them with underscores not operators (minuses aka dashes, etc.)")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hirschbuechler/Documents/Github/DA_report1/vigilant_tribbles/myink_demos.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> m.tester()
#
# File c:\Users\hirschbuechler\Documents\Github\DA_report1\vigilant_tribbles\myink.py:1378, in tester()
#    1376 histo_test()
#    1377 doublebarrel_barberpole()
# -> 1378 statistics_visu()
#
# File c:\Users\hirschbuechler\Documents\Github\DA_report1\vigilant_tribbles\myink.py:1714, in statistics_visu()
#    1712 pe.subplots(ncols=3)
#    1713 pe.suptitle("graphing methods")
# -> 1714 pe.boxplot(y)
#    1715 pe.title("actual boxplot")
#    1717 pe.ax_onward()
#
# File c:\Users\hirschbuechler\Documents\Github\DA_report1\vigilant_tribbles\myink.py:1096, in myinkc.boxplot(self, data, xlabels, meanoffset, ylabel, title, make_canvas, mc, **kwargs)
#    1093 if make_canvas:
#    1094     self.subplots()
# -> 1096 self.get_ax().boxplot(x, data-off, **kwargs)
#    1097 self.plot(1, means+std, marker="^", markerfacecolor=mc, markeredgecolor=mc)
#    1098 self.plot(1, means, marker="s", markerfacecolor=mc, markeredgecolor=mc)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'
