# %%
try:
    import myink as m
except:
    try:
        import vigilant_tribbles.myink as m
    except:
        print("failed to import module directly or via submodule -  mind adding them with underscores not operators (minuses aka dashes, etc.)")

m.tester()
# Out:
# failed to import module directly or via submodule -  mind adding them with underscores not operators (minuses aka dashes, etc.)
# DIPlib -- a quantitative image analysis library
# Version 3.4.1 (Oct 13 2023)
# For more information see https://diplib.org
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
# /home/thomas/git/DA_report1/vigilant_tribbles/myink.py:2355: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(x, k*x + d, 'r', label='Fitted line', c=ele.defaultcolorlist()[1])
# .....
# x_axis=array([1000000., 2000000., 3000000., 4000000.]), np.shape(x_axis)=(4,), np.shape(data)=(5, 5)
# x_axis=array([1000000., 2000000., 3000000., 4000000.]), np.shape(x_axis)=(4,), np.shape(data)=(5, 5)
# /home/thomas/git/DA_report1/vigilant_tribbles/myink.py:2696: UserWarning: FixedFormatter should only be used together with FixedLocator
#   pe.get_ax().set_yticklabels(yticks, ha="center", position=(-0.1, 0))
